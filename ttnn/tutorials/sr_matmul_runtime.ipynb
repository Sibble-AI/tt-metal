# %%
# Set stuff up
import os

os.environ["WH_ARCH_YAML"] = "wormhole_b0_80_arch_eth_dispatch.yaml"
#os.environ["TTNN_CONFIG_OVERRIDES"] = "{\"enable_fast_runtime_mode\": true}"

import ttnn
import numpy
import time 
import torch
#from ttnn.tracer import trace, visualize


torch.manual_seed(0)

device_id = 0
device = ttnn.open_device(device_id=device_id)

ttnn.enable_program_cache(device)
# Out:
# 2024-08-28 15:07:47.361 | WARNING  | ttnn.decorators:operation_decorator:769 - Should ttnn.pearson_correlation_coefficient be migrated to C++?
# 2024-08-28 15:07:47.364 | WARNING  | ttnn.decorators:operation_decorator:769 - Should ttnn.Conv1d be migrated to C++?
# 2024-08-28 15:07:47.374 | WARNING  | ttnn.decorators:operation_decorator:769 - Should ttnn.conv2d be migrated to C++?
# 2024-08-28 15:07:47.378 | WARNING  | ttnn.decorators:operation_decorator:769 - Should ttnn.reshape be migrated to C++?
# 2024-08-28 15:07:47.379 | WARNING  | ttnn.decorators:operation_decorator:769 - Should ttnn.unsqueeze_to_4D be migrated to C++?
# 2024-08-28 15:07:47.380 | WARNING  | ttnn.decorators:operation_decorator:769 - Should ttnn.squeeze be migrated to C++?
# 2024-08-28 15:07:47.381 | WARNING  | ttnn.decorators:operation_decorator:769 - Should ttnn.from_torch be migrated to C++?
# 2024-08-28 15:07:47.382 | WARNING  | ttnn.decorators:operation_decorator:769 - Should ttnn.to_torch be migrated to C++?
# 2024-08-28 15:07:47.383 | WARNING  | ttnn.decorators:operation_decorator:769 - Should ttnn.to_device be migrated to C++?
# 2024-08-28 15:07:47.384 | WARNING  | ttnn.decorators:operation_decorator:769 - Should ttnn.from_device be migrated to C++?
# 2024-08-28 15:07:47.384 | WARNING  | ttnn.decorators:operation_decorator:769 - Should ttnn.allocate_tensor_on_device be migrated to C++?
# 2024-08-28 15:07:47.385 | WARNING  | ttnn.decorators:operation_decorator:769 - Should ttnn.copy_host_to_device_tensor be migrated to C++?
# 2024-08-28 15:07:47.385 | WARNING  | ttnn.decorators:operation_decorator:769 - Should ttnn.deallocate be migrated to C++?
# 2024-08-28 15:07:47.386 | WARNING  | ttnn.decorators:operation_decorator:769 - Should ttnn.reallocate be migrated to C++?
# 2024-08-28 15:07:47.387 | WARNING  | ttnn.decorators:operation_decorator:769 - Should ttnn.load_tensor be migrated to C++?
# 2024-08-28 15:07:47.387 | WARNING  | ttnn.decorators:operation_decorator:769 - Should ttnn.dump_tensor be migrated to C++?
# 2024-08-28 15:07:47.389 | WARNING  | ttnn.decorators:operation_decorator:769 - Should ttnn.as_tensor be migrated to C++?
# 2024-08-28 15:07:47.395 | WARNING  | ttnn.decorators:operation_decorator:769 - Should ttnn.max_pool2d be migrated to C++?
# 2024-08-28 15:07:47.396 | WARNING  | ttnn.decorators:operation_decorator:769 - Should ttnn.max_pool2d_legacy be migrated to C++?
# 2024-08-28 15:07:47.397 | WARNING  | ttnn.decorators:operation_decorator:769 - Should ttnn.avg_pool2d be migrated to C++?
# 2024-08-28 15:07:47.405 | WARNING  | ttnn.decorators:operation_decorator:769 - Should ttnn.conv2d be migrated to C++?
# 2024-08-28 15:07:47.406 | WARNING  | ttnn.decorators:operation_decorator:769 - Should ttnn.max_pool2d be migrated to C++?
# 2024-08-28 15:07:47.407 | WARNING  | ttnn.decorators:operation_decorator:769 - Should ttnn.max_pool2d_legacy be migrated to C++?
# 2024-08-28 15:07:47.407 | WARNING  | ttnn.decorators:operation_decorator:769 - Should ttnn.avg_pool2d be migrated to C++?
# 2024-08-28 15:07:47.409 | WARNING  | ttnn.decorators:operation_decorator:769 - Should ttnn.Conv1d be migrated to C++?
#                  Device | INFO     | Opening user mode device driver
#
# 2024-08-28 15:07:47.493 | INFO     | SiliconDriver   - Detected 1 PCI device : [4]
# 2024-08-28 15:07:47.557 | INFO     | SiliconDriver   - Software version 6.0.0, Ethernet FW version 6.9.0 (Device 0)
# 2024-08-28 15:07:47.557 | INFO     | SiliconDriver   - Software version 6.0.0, Ethernet FW version 6.9.0 (Device 1)
#                   Metal | INFO     | Initializing device 0. Program cache is NOT enabled
#                   Metal | INFO     | AI CLK for device 0 is:   1000 MHz
#                   Metal | INFO     | MMIO Device 0 : Tunnel 0 : Device 0
#                   Metal | INFO     | MMIO Device 0 : Tunnel 0 : Device 1
#                   Metal | INFO     | Enabling program cache on device 0

# %%
# Initialize Tensors

m = 4096
k = 4096
n = 4096

torch.manual_seed(0)

torch_a = torch.rand((m, k))
torch_b = torch.rand((k, n))

a = ttnn.from_torch(torch_a, layout=ttnn.TILE_LAYOUT, device=device, dtype=ttnn.bfloat16)
b = ttnn.from_torch(torch_b, layout=ttnn.TILE_LAYOUT, device=device, dtype=ttnn.bfloat16)

# %%
# Run multiplication 500 times, compare means of runs 0:99 with 400:499

output = ttnn.matmul(a, b, core_grid=ttnn.CoreGrid(y=8, x=8)) # run once to cache mult in on chip program mem

runtimes = [] #save the matmul time for each run
num_iters = 1 
for run in range(0, num_iters): 
    start = time.time()
    output = ttnn.matmul(a, b, core_grid=ttnn.CoreGrid(y=8, x=8))
    end = time.time()
    runtimes.append(end-start)
    ttnn.to_torch(output)

runtimes = [x/1e-6 for x in runtimes] # normalize values to microseconds 
print(f"All runtime array, microseconds: {runtimes}")
print(f"Mean of first 100 runs: {numpy.mean(runtimes[:100])} microseconds")
print(f"Mean of last 100 runs: {numpy.mean(runtimes[100:])} microseconds")

n_chips = 2
mem_bw = 288e9 * n_chips
flops_fp8 = 262e12 * n_chips
size_in_bytes = 2 * (m*k + k*n)
expected_runtime_membw = size_in_bytes/mem_bw/1e-6
expected_runtime_flops = 2*m*k*n/(flops_fp8/4)/1e-6 # assumes Fp16 flops are ~1/4th fp8 flops by implementation
print(f"Expected runtime if membw limited (approximately): {expected_runtime_membw} microseconds")
print(f"Expected runtime if compute limited (approximately): {expected_runtime_flops} microseconds")
print(f"Expected runtime (approximately): {max(expected_runtime_membw, expected_runtime_flops)} microseconds")
# Out:
# All runtime array, microseconds: [157.35626220703125, 212.19253540039062, 176.90658569335938, 179.05235290527344, 189.30435180664062, 174.99923706054688, 182.86705017089844, 190.73486328125, 176.42974853515625, 182.15179443359375, 182.62863159179688, 184.05914306640625, 178.33709716796875, 189.06593322753906, 175.95291137695312, 178.5755157470703, 189.30435180664062, 172.3766326904297, 171.661376953125, 176.90658569335938, 170.23086547851562, 178.81393432617188, 172.13821411132812, 174.2839813232422, 185.25123596191406, 170.23086547851562, 164.27040100097656, 186.44332885742188, 170.70770263671875, 181.1981201171875, 175.47607421875, 167.36984252929688, 169.27719116210938, 177.62184143066406, 171.18453979492188, 170.23086547851562, 181.1981201171875, 169.7540283203125, 173.5687255859375, 176.42974853515625, 170.70770263671875, 166.89300537109375, 181.43653869628906, 172.13821411132812, 168.08509826660156, 179.05235290527344, 171.661376953125, 162.36305236816406, 172.3766326904297, 160.21728515625, 163.55514526367188, 170.4692840576172, 158.54835510253906, 168.80035400390625, 158.3099365234375, 157.35626220703125, 176.90658569335938, 155.92575073242188, 171.18453979492188, 157.83309936523438, 173.09188842773438, 159.97886657714844, 163.79356384277344, 173.80714416503906, 160.9325408935547, 164.27040100097656, 183.10546875, 165.70091247558594, 180.24444580078125, 166.41616821289062, 164.50881958007812, 176.42974853515625, 168.80035400390625, 158.78677368164062, 183.8207244873047, 165.9393310546875, 160.69412231445312, 184.05914306640625, 167.36984252929688, 172.3766326904297, 165.46249389648438, 166.17774963378906, 179.76760864257812, 158.78677368164062, 165.2240753173828, 163.55514526367188, 174.2839813232422, 157.5946807861328, 159.74044799804688, 171.89979553222656, 160.69412231445312, 206.94732666015625, 178.81393432617188, 166.6545867919922, 165.70091247558594, 176.90658569335938, 164.27040100097656, 174.7608184814453, 168.32351684570312, 161.4093780517578, 175.71449279785156, 165.2240753173828, 164.031982421875, 175.23765563964844, 168.80035400390625, 171.89979553222656, 168.08509826660156, 165.46249389648438, 175.47607421875, 169.7540283203125, 174.2839813232422, 165.46249389648438, 163.55514526367188, 170.4692840576172, 166.17774963378906, 202.178955078125, 243.4253692626953, 214.09988403320312, 180.4828643798828, 182.15179443359375, 193.59588623046875, 174.99923706054688, 184.77439880371094, 186.920166015625, 184.53598022460938, 175.95291137695312, 192.40379333496094, 179.290771484375, 187.87384033203125, 186.68174743652344, 187.87384033203125, 179.76760864257812, 191.9269561767578, 181.67495727539062, 180.0060272216797, 194.07272338867188, 178.5755157470703, 184.05914306640625, 195.2648162841797, 177.62184143066406, 180.24444580078125, 189.78118896484375, 182.3902130126953, 180.24444580078125, 197.41058349609375, 180.0060272216797, 188.1122589111328, 189.30435180664062, 191.68853759765625, 188.58909606933594, 198.60267639160156, 178.81393432617188, 177.62184143066406, 179.290771484375, 183.34388732910156, 190.25802612304688, 196.93374633789062, 176.42974853515625, 182.86705017089844, 179.52919006347656, 192.40379333496094, 181.9133758544922, 182.86705017089844, 177.3834228515625, 191.4501190185547, 178.0986785888672, 185.0128173828125, 192.6422119140625, 177.62184143066406, 175.47607421875, 195.2648162841797, 181.43653869628906, 163.55514526367188, 177.86026000976562, 172.13821411132812, 201.70211791992188, 182.3902130126953, 171.18453979492188, 176.42974853515625, 189.78118896484375, 176.6681671142578, 179.76760864257812, 164.50881958007812, 172.61505126953125, 169.7540283203125, 171.661376953125, 173.5687255859375, 175.95291137695312, 171.18453979492188, 165.9393310546875, 165.46249389648438, 184.2975616455078, 167.36984252929688, 160.69412231445312, 173.80714416503906, 160.9325408935547, 162.60147094726562, 173.5687255859375, 165.46249389648438, 168.80035400390625, 164.27040100097656, 173.33030700683594, 167.1314239 ...
# Mean of first 100 runs: 172.31464385986328 microseconds
# Mean of last 100 runs: 169.297456741333 microseconds
# Expected runtime if membw limited (approximately): 116.50844444444445 microseconds
# Expected runtime if compute limited (approximately): 1049.1523165801527 microseconds
# Expected runtime (approximately): 1049.1523165801527 microseconds

# %%
ttnn.close_device(device)
# Out:
#                   Metal | INFO     | Closing device 0
#                   Metal | INFO     | Disabling and clearing program cache on device 0
